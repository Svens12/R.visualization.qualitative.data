# %%
age<-factor(c(2,4,3,3,2,1,1,2,3,4,2,3,3,4,1,3,2,1,4,3,2,4))

# %%
table(age)
# Out:
# age
# 1 2 3 4
# 4 6 7 5

# %%
levels(age)
# Out:
# [1] "1" "2" "3" "4"

# %%
levels(age)<-c('<14','15-24','25-34','>35')

# %%
table(age)
# Out:
# age
#   <14 15-24 25-34   >35
#     4     6     7     5

# %%
barplot(table(age), col=c('blue','red','green','yellow'),ylab='Count')
# Out:
# plot without title

# %%
pie(table(age), col=c('blue','red','green','yellow'))
# Out:
# plot without title
